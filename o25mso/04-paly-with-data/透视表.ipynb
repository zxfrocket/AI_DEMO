# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
# !ls ../homework/
# Out:
# apply_demo.csv     demo_duplicate.csv movie_metadata.csv usa_flights.csv
# city_weather.csv   iris.csv           sales-funnel.xlsx

# %%
df = pd.read_excel('../homework/sales-funnel.xlsx')

# %%
df
# Out:
#     Account                          Name            Rep        Manager  \
# 0    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 1    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 2    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 3    737550  Fritsch, Russel and Anderson   Craig Booker   Debra Henley
# 4    146832                  Kiehn-Spinka  Daniel Hilton   Debra Henley
# 5    218895                     Kulas Inc  Daniel Hilton   Debra Henley
# 6    218895                     Kulas Inc  Daniel Hilton   Debra Henley
# 7    412290                 Jerde-Hilpert     John Smith   Debra Henley
# 8    740150                    Barton LLC     John Smith   Debra Henley
# 9    141962                    Herman LLC    Cedric Moss  Fred Anderson
# 10   163416                   Purdy-Kunde    Cedric Moss  Fred Anderson
# 11   239344                    Stokes LLC    Cedric Moss  Fred Anderson
# ...

# %%
pd.pivot_table(df, index=['Manager','Rep'],values=['Price','Quantity'],columns=['Product'], fill_value=0, aggfunc='sum')
# Out:
#                               Price                              Quantity  \
# Product                         CPU Maintenance Monitor Software      CPU
# Manager       Rep
# Debra Henley  Craig Booker    65000        5000       0    10000        2
#               Daniel Hilton  105000           0       0    10000        4
#               John Smith      35000        5000       0        0        1
# Fred Anderson Cedric Moss     95000        5000       0    10000        3
#               Wendy Yule     165000        7000    5000        0        7
#
#
# Product                     Maintenance Monitor Software
# Manager       Rep
# Debra Henley  Craig Booker            2       0        1
#               Daniel Hilton           0       0        1
#               John Smith              2       0        0
# Fred Anderson Cedric Moss             1       0        1
#               Wendy Yule              3       2        0

# %%
df = pd.read_csv('../homework/Sales.csv')
table = pd.pivot_table(df, index=['Country','Region', 'City'], columns=['Name'], 
                       values=['Price', 'Gross_Profit'], fill_value=0, aggfunc='sum')
table
# Out:
#                                            Gross_Profit                  \
# Name                                  Jacob P. Williams Kathy A. Duncan
# Country   Region       City
# Australia NSW          Sydney                   12583.0         81109.0
#           Victoria     Melbourne               -98492.0        -70796.0
# Canada    BC           East Vancouver           95202.0        -29971.0
#                        Tsawassen               121221.0        -56346.0
#                        Vancouver              -121077.0        -23961.0
#           Qu?bec       Montr?al                -37600.0        -70774.0
#                        Ste-Hyacinthe             6642.0        -65005.0
# Spain     Asturias     Oviedo                   29542.0        -78163.0
# UK        Kent         Sevenoaks                24117.0          5203.0
#           Lancashire   Hedge End               -52368.0        -61464.0
#           N. Yorkshire Harrogate               -54493.0        212802.0
# ...
